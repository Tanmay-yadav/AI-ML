# %% [markdown]
#  # Problem with Perceptron Trick
#
#  - we are not very confident about  Model or the line that the perceptron trick gives us.
#  - It doesn't tell how much better our classification model is.
# ![image.png](attachment:image.png)
#
# # Loss Function
# - Loss function tells us the error, and with the help of loss function we can update the weights so that we can get the minimum errored model which make the prediction closest to the actual output.
# - The perceptron Loss function is
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# - Here We want to find the value of w1,w2,b. so that the value of this expression(perceptron loss Functin) is minimum.
#
#
# [Sklearn documentation on Loss functions](https://scikit-learn.org/stable/modules/sgd.html#mathematical-formulation)
#
#  ## Exlanation of Loss Function
#  ![image-4.png](attachment:image-4.png)
#
#  ## Gradient Descent
#  ![image-9.png](attachment:image-9.png)
#  ![image-6.png](attachment:image-6.png)
#  ![image-7.png](attachment:image-7.png)
#  ![image-8.png](attachment:image-8.png)
#
#  ## More Loss Function
#  - Perceptron is very flexible in terms of output, by changing the activation function  we can change the output.
#  - Like instesd of 1,-1 as output we can use sigmoid function which gives probability instead of step function used in percerptron  and so on.
#  - perceptron and logistic regression are same function only and only if perceptron's activation function is sigmoid and loss function is binary cross entropy.
#   ![image-5.png](attachment:image-5.png)

# %% [markdown]
# # Problem wit Perceptron
# - perceptron can classify only the Linear Data.

# %%
from sklearn.datasets import make_classification
import numpy as np
X, y = make_classification(n_samples=100, n_features=2, n_informative=1,n_redundant=0,
                           n_classes=2, n_clusters_per_class=1, random_state=41,hypercube=False,class_sep=15)

# %%
X.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 plt.figure(figsize=(10,6))
#       3 plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
#
# File e:\WORK\AI-ML\venv\Lib\site-packages\matplotlib\__init__.py:161
#     157 from packaging.version import parse as parse_version
#     159 # cbook must import matplotlib only within function
#     160 # definitions, so it is safe to import from it here.
# --> 161 from . import _api, _version, cbook, _docstring, rcsetup
#     162 from matplotlib._api import MatplotlibDeprecationWarning
#     163 from matplotlib.rcsetup import cycler  # noqa: F401
#
# File e:\WORK\AI-ML\venv\Lib\site-packages\matplotlib\rcsetup.py:26
#      23 import numpy as np
#      25 from matplotlib import _api, cbook
# ---> 26 from matplotlib.backends import BackendFilter, backend_registry
# ...

# %%
def perceptron(X,y):
    
    w1=w2=b=1
    lr = 0.1
    
    for j in range(1000):
    
        for i in range(X.shape[0]):

            # check condition
            z = w1*X[i][0] + w2*X[i][1] + b

            if z*y[i] < 0:
                w1 = w1 + lr*y[i]*X[i][0]
                w2 = w2 + lr*y[i]*X[i][1]
                b = b + lr*y[i]
            
    return w1,w2,b

# %%
w1,w2,b = perceptron(X,y)

# %%
b
# Out:
# np.float64(1.3000000000000003)

# %%
m = -(w1/w2)
c = -(b/w2)

print(m,c)
# Out:
# -4.531321834268464 -5.851870329508209

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input + c

plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 x_input = np.linspace(-3,3,100)
#       2 y_input = m*x_input + c
# ----> 4 plt.figure(figsize=(10,6))
#       5 plt.plot(x_input,y_input,color='red',linewidth=3)
#       6 plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
#
# NameError: name 'plt' is not defined
