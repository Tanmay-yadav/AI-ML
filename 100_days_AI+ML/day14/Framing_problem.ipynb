# %% [markdown]
# # How to Frame a Machine Learning Problem

# %% [markdown]
# ### 1.Business problem to ML Problem
# ### 2.Type of problem
# ### 3.Current Solution
# ### 4.Getting Data
# ### 5. Metrics to measure
# ### 6.Online vs Batch
# ### 7.Check Assumptions

# %%
#   how to frame a machine learning problem
#   and how to approach solving it using machine learning techniques.   
#   It covers the essential steps from understanding the problem domain,
#   gathering and preparing data, selecting appropriate algorithms,
#   training and evaluating models, to deploying solutions in real-world scenarios. 
#   This guide is designed for beginners and intermediate practitioners
#   looking to enhance their skills in machine learning problem-solving.
#   This comprehensive guide provides insights into
#   Machine Learning Problem-Solving Guide

# %%
#
