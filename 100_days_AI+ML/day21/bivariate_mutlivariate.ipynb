# %% [markdown]
# # Multivariate and Bivariate Analysis

# %%
import pandas as pd 
import seaborn as sns

# %%
tips = pd.read_csv('E:\\WORK\\AI-ML\\data\\tip.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic =pd.read_csv('E:\\WORK\\AI-ML\\data\\titanic.csv')
titanic.head()
sns.scatterplot(data=titanic,x ='Pclass',y ='Age')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
iris =pd.read_csv('E:\\WORK\\AI-ML\\data\\iris.csv')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # 1. Scatterplot (Numerical- Numerical)

# %%
sns.scatterplot(data=tips ,x= "total_bill",y="tip",hue='sex',style='smoker',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # 2. Bar plot(Numerical-Categorical)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
sns.barplot(data=titanic,x='Pclass',y='Fare',hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# # 3.Box Plot(Numerical-Categorical)

# %%
sns.boxplot(data=titanic,x='Sex',y='Age',hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# # 4.Distplot(Numerical-Categorical)

# %%
# sns.distplot(titanic[titanic['Survived']==0]['Age'],hist=False)
# sns.distplot(titanic[titanic['Survived']==1]['Age'],hist=False)

# %% [markdown]
# # 5. HeatMap(Categorical-Categorical)

# %%
titanic.head(3)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S
# 2  62.0      0      0  240276  9.6875   NaN        Q

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
(titanic.groupby('Sex')['Survived'].mean()*100)
# Out:
# Sex
# female    100.0
# male        0.0
# Name: Survived, dtype: float64

# %%
# Run this on the FULL dataframe to get the real comparison
real_rates = titanic.groupby('Sex')['Survived'].mean() * 100
print(real_rates)
# Out:
# Sex
# female    100.0
# male        0.0
# Name: Survived, dtype: float64

# %%
# Survived = titanic['Survived']==0

# %%
titanic.groupby('Sex')['Survived'].value_counts()
# Out:
# Sex     Survived
# female  1           152
# male    0           266
# Name: count, dtype: int64

# %% [markdown]
# # ClusterMap(Categorical-Categorical)

# %%
# %pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
sns.clustermap(pd.crosstab(titanic['Parch'],titanic['Survived']))

# %% [markdown]
# # 7. Pairplot

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,hue='species')

# %% [markdown]
# # 8.Lineplot(Numerical-Numerical)

# %%
# Time based analysis is done in lineplot
flights = pd.read_csv('E:\\WORK\\AI-ML\\data\\flights.csv')
# flights.head()
new=flights.groupby('year').sum().reset_index()

# %%
sns.lineplot(new['year'],new['passengers'] )
