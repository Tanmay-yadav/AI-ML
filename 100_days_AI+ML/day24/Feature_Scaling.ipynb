# %% [markdown]
# # What is feature scaling?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Why do we need Feature Scaling?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Types of Feature Scaling

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Standardization

# %% [markdown]
# ## Standardization-Intuition

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Code part

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv('E:\\WORK\\AI-ML\\data\\Social_Network_Ads.csv')

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df= df.iloc[:,2:]

# %%
df.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 338   38            55000          0
# 263   35            72000          0
# 335   36            54000          0
# 68    22            63000          0
# 101   28            59000          0

# %% [markdown]
# # Train test split

# %%
# %pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop('Purchased',axis=1),df['Purchased'],test_size=0.3,random_state=0)
X_train.shape,X_test.shape
# Out:
# ((280, 2), (120, 2))

# %% [markdown]
# # StandarScaler

# %%
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()
# fit the scaler to the train set, it will learn the parameters
scaler.fit(X_train) 
#  transform train and test sets 
X_train_scaled = scaler.transform(X_train) 
X_test_scaled = scaler.transform(X_test)

# %%
scaler.mean_
# Out:
# array([3.78642857e+01, 6.98071429e+04])

# %%
X_train_scaled
# Out:
# array([[-1.1631724 , -1.5849703 ],
#        [ 2.17018137,  0.93098672],
#        [ 0.0133054 ,  1.22017719],
#        [ 0.20938504,  1.07558195],
#        [ 0.40546467, -0.48604654],
#        [-0.28081405, -0.31253226],
#        [ 0.99370357, -0.8330751 ],
#        [ 0.99370357,  1.8563962 ],
#        [ 0.0133054 ,  1.24909623],
#        [-0.86905295,  2.26126285],
#        [-1.1631724 , -1.5849703 ],
#        [ 2.17018137, -0.80415605],
#        [-1.35925203, -1.46929411],
#        [ 0.40546467,  2.2901819 ],
#        [ 0.79762394,  0.75747245],
#        [-0.96709276, -0.31253226],
#        [ 0.11134522,  0.75747245],
#        [-0.96709276,  0.55503912],
#        [ 0.30742485,  0.06341534],
#        [ 0.69958412, -1.26686079],
#        [-0.47689368, -0.0233418 ],
#        [-1.7514113 ,  0.3526058 ],
#        [-0.67297331,  0.12125343],
#        [ 0.40546467,  0.29476771],
#        [-0.28081405,  0.06341534],
#        [-0.47689368,  2.2901819 ],
#        [ 0.20938504,  0.03449629],
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
X_train_scaled= pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled= pd.DataFrame(X_test_scaled, columns=X_test.columns)
X_train_scaled.head()
#  this converts the numpy array back to dataframe for better visualization
# Out:
#         Age  EstimatedSalary
# 0 -1.163172        -1.584970
# 1  2.170181         0.930987
# 2  0.013305         1.220177
# 3  0.209385         1.075582
# 4  0.405465        -0.486047

# %%
np.round(X_train_scaled.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean     0.0              0.0
# std      1.0              1.0
# min     -1.9             -1.6
# 25%     -0.8             -0.8
# 50%     -0.1              0.0
# 75%      0.8              0.5
# max      2.2              2.3

# %% [markdown]
# # Effect of scaling

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(12,5))
ax1.scatter(X_train['Age'],X_train['EstimatedSalary'])
ax1.set_title('Before Scaling')
ax2.scatter(X_train_scaled['Age'],X_train_scaled['EstimatedSalary'],color='red')
ax2.set_title('After Scaling')  
plt.show()

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(12,5))
# before scaling
ax1.set_title('Before Scaling')
sns.kdeplot(X_train['Age'],ax=ax1,fill=False,label='Age')
sns.kdeplot(X_train['EstimatedSalary'],ax=ax1,fill=False,color='magenta',label='EstimatedSalary')
# after scaling 
ax2.set_title('After Standard Scaling')
sns.kdeplot(X_train_scaled['Age'],ax=ax2,fill=False,color='red',label='Age')
sns.kdeplot(X_train_scaled['EstimatedSalary'],ax=ax2,fill=False,color='green',label='EstimatedSalary')
plt.show()

# %% [markdown]
# # Comparison of Distributions

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(10,4))
# before scaling
ax1.set_title('Age Distribution Before Scaling')
sns.kdeplot(X_train['Age'],ax=ax1)
# after scaling 
ax2.set_title('Age Distribution After Standard Scaling')
sns.kdeplot(X_train_scaled['Age'],ax=ax2,color='red')   
plt.show()

# %% [markdown]
# # Why is scaling is important?

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr_scaled= LogisticRegression()

# %%
lr.fit(X_train,y_train)
lr_scaled.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
y_pred =lr.predict(X_test)
y_pred_scaled= lr_scaled.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score

print("Actual",accuracy_score(y_test,y_pred))
print("After Scaling",accuracy_score(y_test,y_pred_scaled))
# Out:
# Actual 0.875
# After Scaling 0.8666666666666667

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()
dt_scaled=DecisionTreeClassifier()

# %%
dt.fit(X_train,y_train)
dt_scaled.fit(X_train_scaled,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred =dt.predict(X_test)
y_pred_scaled= dt_scaled.predict(X_test_scaled)

# %%
print("Actual",accuracy_score(y_test,y_pred))
print("After Scaling",accuracy_score(y_test,y_pred_scaled))
# Out:
# Actual 0.875
# After Scaling 0.8666666666666667

# %%
df.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %% [markdown]
# # Effect of Outliers

# %%
df = pd.concat(
    [
        df,
        pd.DataFrame({
            'Age': [5, 90, 95],
            'EstimatedSalary': [15000, 200000, 250000],
            'Purchased': [0, 1, 1]
        })
    ],
    ignore_index=True
)
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 401   90           200000          1
# 402   95           250000          1
# 403    5            15000          0
# 404   90           200000          1
# 405   95           250000          1
#
# [406 rows x 3 columns]

# %%
plt.scatter(df['Age'],df['EstimatedSalary'])

# %% [markdown]
# # When to use standardization
# ![image.png](attachment:image.png)

# %% [markdown]
# [Youtube video](https://www.youtube.com/watch?v=1Yw9sC0PNwY&list=PLKnIA16_Rmvbr7zKYQuBfsVkjoLcJgxHH&index=24)
