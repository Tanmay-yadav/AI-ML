# %% [markdown]
# # API

# %%
# what is api ?
# Application Programming Interface 
# it is a set of rules that allows different software entities to communicate with each other.
# APIs define the methods and data formats that applications can use to request and exchange information.
# APIs are used to enable integration between different systems, allowing them to work together and share data or functionality.
# they are commonly used in web development to allow different web services and applications to interact with each other.
