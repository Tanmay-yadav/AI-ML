# %% [markdown]
# # Understanding your data

# %% [markdown]
# ## 1. Asking BAsic Questions
# ## 2. EDA(Exploratory data analysis)- univariate
# ## 3. EDA -Multivariate
# ## 4. Pandas Profilers

# %% [markdown]
# # TODAY Asking basic Questions

# %%
import pandas as pd

df =pd.read_csv('E:\\WORK\\AI-ML\\100_days_AI+ML\\day15\\placement.csv')

# %% [markdown]
# ## 1. How big is the data?

# %%
df.shape

# %% [markdown]
# ## 2. How does the data look like?

# %%
df.head()
df.sample(5)
# df.sample is used to fetch random rows from the dataframe 
# df.head() is used to fetch top rows from the dataframe

# %% [markdown]
# ## 3. What is the data type of the cols?

# %%
df.info()
# df.info() gives the summary of the dataframe including the data types and non-null counts 
# df.describe()
# df.describe() gives the statistical summary of numerical columns in the dataframe

# %% [markdown]
# ## 4. Are there any missing values?

# %%
df.isnull().sum()
# To check missing values in each column

# %% [markdown]
# ## 5. How does the data look mathematically?

# %%
df.describe()
# df.describe() gives the statistical summary of numerical columns in the dataframe

# %% [markdown]
# ## 6. Are there duplicate values?

# %%
df.duplicated().sum()
# df.duplicated().sum() gives the count of duplicate rows in the dataframe
# Out:
# np.int64(0)

# %% [markdown]
# ## 7. How is the correlation between cols?

# %%
df.corr()['iq']
# To find correlation between numerical columns
# The correlation values range from -1 to 1
# A value close to 1 indicates a strong positive correlation, meaning that as one variable increases, the other variable tends to increase as well.
# A value close to -1 indicates a strong negative correlation, meaning that as one variable increases, the other variable tends to decrease.
# A value close to 0 indicates little to no correlation between the variables.
# Out:
# Unnamed: 0   -0.019080
# cgpa         -0.098791
# iq            1.000000
# placement    -0.083031
# Name: iq, dtype: float64
