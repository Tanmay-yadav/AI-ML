# %% [markdown]
# # Basics python

# %%
for i in [1,2,3,4,5]:
    print("i==" + str(i))
    for j in [1,2,3,4,5]:
        print("j==" + str(j))
        print("i+j==" + str(i+j))
    print("i again ==" + str(i))
print("loop done")

# %%
#=========================== MODULES================================================== 
# certain features of python are loaded by default . In order to use these feature,you'll need to import the modules that contain them:
""""""
import re
my_regex=re.compile("[0-9]+",re.I)

# %%
# ===========FUNCTIONS===================
"""A fuction is a rule for taking zero or more inouts and returning a corresponfing 
output. In python we typically define functions usinf def"""
def double(x):
    """this is where you put an optimal docstring
    that explains what the function does.
    for example this function doubles its input"""
    return x*2
print(double(2))
# Out:
# 4

# %%
# ==============Strings===========================
"""Strings are sequences of characters. We can create them by enclosing text in quotes:
double quated ="hello."
single quated='goodbye'
triple quoted
"""

# %% [markdown]
# # lists
# ![image.png](attachment:image.png)

# %% [markdown]
# # Tuples
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
