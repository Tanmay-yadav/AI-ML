# %% [markdown]
# # Python Syntax
#
# ## What You'll Learn
# - Basic Python syntax
# - Code structure
# - Comments
# - Statements and expressions

# %% [markdown]
# ## Syntax Basics
#
# Python is known for its clean, readable syntax.
#
# ### Key Features
# 1. **Indentation** - Python uses indentation to define code blocks
# 2. **No semicolons** - Statements end with newline
# 3. **Case sensitive** - `x` and `X` are different
# 4. **Dynamic typing** - Variables don't need type declarations

# %%
# This is a comment - single line

"""
This is a multi-line comment or docstring.
It can span multiple lines.
"""

# Variables and assignments
x = 10
y = 20
print(x + y)
