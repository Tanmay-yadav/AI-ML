# %% [markdown]
# # Pythonic Code
#
# ## What You'll Learn
# - PEP 8 style guide
# - Zen of Python
# - Idiomatic Python
# - Code smells and refactoring

# %%
# The Zen of Python
import this

# %%
# Pythonic vs Non-Pythonic

# Not Pythonic
for i in range(len(items)):
    print(items[i])

# Pythonic
for item in items:
    print(item)

# Not Pythonic
if len(my_list) > 0:
    print("List has items")

# Pythonic
if my_list:
    print("List has items")
