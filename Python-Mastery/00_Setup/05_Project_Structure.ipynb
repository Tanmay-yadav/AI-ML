# %% [markdown]
# # Project Structure
#
# ## What You'll Learn
# - Organizing a Python project
# - Module structure
# - Package organization
# - Best practices

# %% [markdown]
# ## Recommended Project Structure
#
# ```
# my_project/
# ├── README.md
# ├── LICENSE
# ├── requirements.txt
# ├── setup.py
# ├── my_package/
# │   ├── __init__.py
# │   ├── main.py
# │   ├── utils.py
# │   └── config.py
# ├── tests/
# │   ├── __init__.py
# │   ├── test_main.py
# │   └── test_utils.py
# ├── docs/
# │   └── index.md
# └── .gitignore
# ```
