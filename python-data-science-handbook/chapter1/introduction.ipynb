# %% [markdown]
# # Running External Code:%run

# %%
def square(x):
    """Square a number."""
    return x ** 2

for N in range(1,4):
    print(f"The square of {N} is {square(N)}")
# Out:
# The square of 1 is 1
# The square of 2 is 4
# The square of 3 is 9

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(In)
print(Out)
# Out:
# ['', 'def square(x):\n    """Square a number."""\n    return x ** 2\n\nfor N in range(1,4):\n    print(f"The square of {N} is {square(N)}")', "get_ipython().run_line_magic('run', 'introduction.ipynb')", 'print(In)', 'print(In)\nprint(Out[2])', 'print(In)\nprint(Out)']
# {}

# %% [markdown]
# # Timing Code Execution:%timeit
