# %% [markdown]
# # What is Statistics?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Types of Statistics
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
